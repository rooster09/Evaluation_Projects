# %%
import pandas as pd
import numpy as np

# %%
maindt = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/loan_prediction.csv")

# %%
maindt
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
maindt.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
maindt.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# Null values need to be processed

# %%
maindt.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
maindt.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
maindt.Gender.value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
maindt['Gender'] = maindt['Gender'].fillna('Male')

# %%
maindt.Married.value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
maindt['Married'] = maindt['Married'].fillna('Yes')

# %%
maindt.Dependents.value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
maindt.Dependents = maindt['Dependents'].fillna('O')

# %%
maindt.Self_Employed.value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
maindt.Self_Employed = maindt['Self_Employed'].fillna('No')

# %%
maindt
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
maindt.LoanAmount.value_counts()
# Out:
# 120.0    20
# 110.0    17
# 100.0    15
# 160.0    12
# 187.0    12
#          ..
# 211.0     1
# 250.0     1
# 62.0      1
# 85.0      1
# 436.0     1
# Name: LoanAmount, Length: 203, dtype: int64

# %%
maindt.LoanAmount = maindt['LoanAmount'].fillna((maindt.LoanAmount.mean()))

# %%
maindt.Loan_Amount_Term.value_counts()
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 84.0       4
# 240.0      4
# 120.0      3
# 36.0       2
# 60.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
maindt.Loan_Amount_Term = maindt['Loan_Amount_Term'].fillna((maindt.Loan_Amount_Term.mean()))

# %%
maindt.Credit_History.value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
maindt.Credit_History = maindt['Credit_History'].fillna((maindt.Credit_History.mean()))

# %%
maindt
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
maindt.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# Null values are taken care of

# %%
maindt
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# Loan ID to be dropped its not useful for model building

# %%
maindt2 = maindt.copy()

# %%
maindt.drop('Loan_ID', axis=1, inplace=True)

# %%
maindt.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %% [markdown]
# Label encoding object datatype columns

# %%
from sklearn.preprocessing import LabelEncoder 
le = LabelEncoder()
maindt["Gender"] = le.fit_transform(maindt["Gender"])
maindt["Married"] = le.fit_transform(maindt["Married"])
maindt["Education"] = le.fit_transform(maindt["Education"])
maindt["Self_Employed"] = le.fit_transform(maindt["Self_Employed"])
maindt["Property_Area"] = le.fit_transform(maindt["Property_Area"])
maindt["Loan_Status"] = le.fit_transform(maindt["Loan_Status"])

# %%
maindt
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0          0          0              0             5849
# 1         1        1          1          0              0             4583
# 2         1        1          0          0              1             3000
# 3         1        1          0          1              0             2583
# 4         1        0          0          0              0             6000
# ..      ...      ...        ...        ...            ...              ...
# 609       0        0          0          0              0             2900
# 610       1        1         3+          0              0             4106
# 611       1        1          1          0              0             8072
# 612       1        1          2          0              0             7583
# 613       0        0          0          0              1             4583
#
# ...

# %% [markdown]
# There is 3+	string value in dependents

# %%
maindt3 = maindt.copy()

# %%
maindt3
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0          0          0              0             5849
# 1         1        1          1          0              0             4583
# 2         1        1          0          0              1             3000
# 3         1        1          0          1              0             2583
# 4         1        0          0          0              0             6000
# ..      ...      ...        ...        ...            ...              ...
# 609       0        0          0          0              0             2900
# 610       1        1         3+          0              0             4106
# 611       1        1          1          0              0             8072
# 612       1        1          2          0              0             7583
# 613       0        0          0          0              1             4583
#
# ...

# %%
#maindt["Credit_History"] = pd.to_numeric(maindt["Credit_History"])
maindt['Credit_History'].replace(['3+'],
                             '3', inplace = True)

# %%
cat_col = ['Gender','Married','Dependents','Education','Self_Employed','Property_Area','Loan_Status']
le = LabelEncoder()
for col in cat_col:
    maindt[col] = le.fit_transform(maindt[col])

# %% [markdown]
# Outlier check

# %%
plt.figure(figsize=(20,50))
colcount = len(maindt.columns)
x=1
for col in maindt:
    if x <= colcount:
        ax= plt.subplot(10,3,x)
        sns.distplot(maindt[col])
       # plt.scatter(y=maindt[col],x=maindt['quality'])
        plt.xlabel(col,fontsize=10)
    x=x+1
plt.show()
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
maindt.skew()
# Out:
# Gender              -1.648795
# Married             -0.644850
# Dependents           1.089068
# Education            1.367622
# Self_Employed        2.159796
# ApplicantIncome      6.539513
# CoapplicantIncome    7.491531
# LoanAmount           2.726601
# Loan_Amount_Term    -2.389680
# Credit_History      -1.963600
# Property_Area       -0.066196
# Loan_Status         -0.809998
# dtype: float64

# %% [markdown]
# Plotting box plot

# %%
plt.figure(figsize=(20,50))
colcount = len(maindt.columns)
x=1
for col in maindt:
    if x <= colcount:
        ax= plt.subplot(10,3,x)
        sns.boxplot(maindt[col],orient='v')
        plt.xlabel(col,fontsize=10)
    x=x+1
plt.show()
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
# ...

# %% [markdown]
# Removing outliers with the help of z score

# %%
from scipy.stats import zscore
z_score = np.abs(zscore(maindt))

# %%
maindt = maindt[(z_score<3).all(axis = 1)]

# %%
maindt.skew()
# Out:
# Gender              -1.622920
# Married             -0.630211
# Dependents           1.134133
# Education            1.306588
# Self_Employed        2.252848
# ApplicantIncome      2.148522
# CoapplicantIncome    1.350517
# LoanAmount           1.113132
# Loan_Amount_Term    -2.077031
# Credit_History      -1.921860
# Property_Area       -0.055332
# Loan_Status         -0.822635
# dtype: float64

# %% [markdown]
# Checking for multi colinearity

# %%
plt.figure(figsize=(10,10))
sns.heatmap(maindt.corr(), color = "k", annot=True  )
# Out:
# <AxesSubplot:>

# %% [markdown]
# No positive correlation found

# %%
plt.figure(figsize=(20,50))
colcount = len(maindt.columns)
x=1
for col in maindt:
    if x <= colcount:
        ax= plt.subplot(10,3,x)
        sns.distplot(maindt[col])
       # plt.scatter(y=maindt[col],x=maindt['quality'])
        plt.xlabel(col,fontsize=10)
    x=x+1
plt.show()
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Scaling the data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x= maindt.drop(columns=['Loan_Status'])
y= maindt['Loan_Status']
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x.head()
# Out:
#      Gender   Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  0.477137 -1.362511   -0.737994  -0.541961      -0.380580         0.399266
# 1  0.477137  0.733939    0.158475  -0.541961      -0.380580        -0.028020
# 2  0.477137  0.733939   -0.737994  -0.541961       2.627567        -0.562297
# 3  0.477137  0.733939   -0.737994   1.845150      -0.380580        -0.703039
# 4  0.477137 -1.362511   -0.737994  -0.541961      -0.380580         0.450230
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0          -0.861036    0.184585          0.239408        0.456461
# 1           0.052840   -0.143355          0.239408        0.456461
# 2          -0.861036   -1.247642          0.239408        0.456461
# 3           0.567956   -0.285844          0.239408        0.456461
# 4          -0.861036    0.088189          0.239408        0.456461
#
#    Property_Area
# 0       1.227472
# 1      -1.306522
# 2       1.227472
# 3       1.227472
# ...

# %% [markdown]
# Building model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split , cross_val_score
import numpy as np
from sklearn.svm import SVC
from sklearn.metrics import classification_report,confusion_matrix
lrm = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=29)
lrm.fit(x_train,y_train)

lrscore = lrm.score(x_test,y_test)
print("Model Score", lrscore )
lrcvscore = cross_val_score(lrm,x,y,cv=5)
print("Cross Valudition", np.mean(lrcvscore) )
# Out:
# Model Score 0.24648424673508607
# Cross Valudition 0.29615722031010694

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)

dtcscore = dtc.score(x_test,y_test)
print("Model Score", dtcscore )
dtccvscore = cross_val_score(dtc,x,y,cv=5)
print("Cross Valudition", np.mean(dtccvscore) )
dtcpred = dtc.predict(x_test)
print("Classification Report", classification_report(y_test,dtcpred))
print("Confusion Matrix:\n",confusion_matrix(dtcpred, y_test))
# Out:
# Model Score 0.696551724137931
# Cross Valudition 0.7175262368815593
# Classification Report               precision    recall  f1-score   support
#
#            0       0.65      0.53      0.58        58
#            1       0.72      0.80      0.76        87
#
#     accuracy                           0.70       145
#    macro avg       0.68      0.67      0.67       145
# weighted avg       0.69      0.70      0.69       145
#
# Confusion Matrix:
#  [[31 17]
#  [27 70]]

# %% [markdown]
# Cv is 71% and accuracy 70 difference of 1%

# %%
from sklearn.ensemble import RandomForestClassifier
rfcmodel = RandomForestClassifier()
rfcmodel.fit(x_train,y_train)

rfcscore = rfcmodel.score(x_test,y_test)
print("Model Score", dtcscore )
rfccvscore = cross_val_score(rfcmodel,x,y,cv=5)
print("Cross Valudition", np.mean(rfccvscore) )
rfcpred = rfcmodel.predict(x_test)
print("Cross Valudition", classification_report(y_test,rfcpred))
print("Confusion Matrix:\n",confusion_matrix(rfcpred, y_test))
# Out:
# Model Score 0.696551724137931
# Cross Valudition 0.8006896551724138
# Cross Valudition               precision    recall  f1-score   support
#
#            0       0.90      0.45      0.60        58
#            1       0.72      0.97      0.83        87
#
#     accuracy                           0.76       145
#    macro avg       0.81      0.71      0.71       145
# weighted avg       0.79      0.76      0.74       145
#
# Confusion Matrix:
#  [[26  3]
#  [32 84]]

# %% [markdown]
# Cv is 80% and accuracy 76 difference of 4%

# %%
svcmodel = SVC()
svcmodel.fit(x_train,y_train)
svcscore = svcmodel.score(x_test,y_test)
print("Model Score", svcscore )
svccvscore = cross_val_score(svcmodel,x,y,cv=5)
print("Cross Valudition", np.mean(svccvscore) )
svcpred = svcmodel.predict(x_test)
print("Cross Valudition", classification_report(y_test,svcpred))
print("Confusion Matrix:\n",confusion_matrix(svcpred, y_test))
# Out:
# Model Score 0.7793103448275862
# Cross Valudition 0.8145877061469265
# Cross Valudition               precision    recall  f1-score   support
#
#            0       0.96      0.47      0.63        58
#            1       0.74      0.99      0.84        87
#
#     accuracy                           0.78       145
#    macro avg       0.85      0.73      0.74       145
# weighted avg       0.83      0.78      0.76       145
#
# Confusion Matrix:
#  [[27  1]
#  [31 86]]

# %% [markdown]
# Cv is 81% and accuracy 78 difference of 3%

# %%
from sklearn.ensemble import AdaBoostClassifier
adbc = AdaBoostClassifier()
adbc.fit(x_train,y_train)
adbcscore = adbc.score(x_test,y_test)
print("Model Score", adbcscore )
adbccvscore = cross_val_score(adbc,x,y,cv=5)
print("Cross Valudition", np.mean(adbccvscore) )
adbcpred = adbc.predict(x_test)
print("Cross Valudition", classification_report(y_test,adbcpred))
print("Confusion Matrix:\n",confusion_matrix(adbcpred, y_test))
# Out:
# Model Score 0.7448275862068966
# Cross Valudition 0.7817091454272863
# Cross Valudition               precision    recall  f1-score   support
#
#            0       0.86      0.43      0.57        58
#            1       0.72      0.95      0.82        87
#
#     accuracy                           0.74       145
#    macro avg       0.79      0.69      0.70       145
# weighted avg       0.77      0.74      0.72       145
#
# Confusion Matrix:
#  [[25  4]
#  [33 83]]

# %% [markdown]
# Cv is 78% and accuracy 74 difference of 4%

# %% [markdown]
# SVC model turns out to be the best model

# %% [markdown]
# Using Hyper parameter tuning to determine the max output

# %%
param = {
              'kernel' : ['linear', 'poly', 'rbf', 'sigmoid'],
              'gamma' : ['scale', 'auto','float'],
              'random_state' : [69, 43,58,75]
              
             }

# %% [markdown]
# param = {'criterion' : ["gini", "entropy"],
#               'n_jobs' : [2, 1, -1],
#               'min_samples_split' : [2, 3, 4],
#               'max_depth' : [20, 25, 30],
#               'random_state' : [42, 45, 111]
#              }

# %%
from sklearn.model_selection import GridSearchCV
gscv = GridSearchCV(SVC(),param,cv=5)

# %%
gscv.fit(x_train,y_train)
gscv.best_params_
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rooster\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rooster\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 214, in fit
#     raise ValueError(
# ValueError: When 'gamma' is a string, it should be either 'scale' or 'auto'. Got 'float' instead.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
# ...

# %%
model = SVC(gamma='scale',kernel='linear',random_state=69)
#model = RandomForestClassifier(criterion='entropy',max_depth=20,min_samples_split=3,n_jobs = 2, random_state = 42)

# %%
    from sklearn.metrics import r2_score
    from sklearn.metrics import mean_squared_error,mean_absolute_error
    model.fit(x_train,y_train)
    pred=model.predict(x_test)
    print('R2 score = ', r2_score(y_test,pred))
    print('Mean square error =',mean_squared_error(y_test,pred))
    print('Absolute error =',mean_absolute_error(y_test,pred))
    print('RMS value =',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score =  0.02298850574712652
# Mean square error = 0.23448275862068965
# Absolute error = 0.23448275862068965
# RMS value = 0.4842341981115023

# %%
import joblib
joblib.dump(model, "Model1.pkl")
# Out:
# ['Model1.pkl']
