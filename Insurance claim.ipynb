# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
maindt = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv')
maindt.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
maindt.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
maindt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
maindt.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
maindt.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %%
    maindt._c39.value_counts()
# Out:
# Series([], Name: _c39, dtype: int64)

# %%
maindt._c39
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 995   NaN
# 996   NaN
# 997   NaN
# 998   NaN
# 999   NaN
# Name: _c39, Length: 1000, dtype: float64

# %% [markdown]
# _c39 has all values as null so will be dropped Rest there are no null values

# %%
maindt.drop('_c39', axis=1, inplace=True)

# %% [markdown]
# Making some visualization to better understand

# %%
sns.countplot(maindt['policy_state'], hue=maindt['fraud_reported'])
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='policy_state', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.stripplot(maindt['auto_make'], maindt['total_claim_amount'])
plt.show()
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(13,5))
sns.countplot(maindt['auto_make'], hue=maindt['fraud_reported'])
plt.show()
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.pie(maindt['fraud_reported'].value_counts(), labels=['Yes', 'No'], shadow=True)
plt.show()

# %%
maindt.head(10)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
# 5                 256   39         104594       12-10-2006           OH
# 6                 137   34         413978       04-06-2000           IN
# 7                 165   37         429027       03-02-1990           IL
# 8                  27   33         485665       05-02-1997           IL
# 9                 212   42         636550       25-07-2011           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# ...

# %% [markdown]
# On 	police_report_available column '?' can be seen so replacing it with null values

# %%
maindt = maindt.replace('?', np.nan)

# %%
maindt.isnull().sum()
# Out:
# months_as_customer               0
# age                              0
# policy_number                    0
# policy_bind_date                 0
# policy_state                     0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_zip                      0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_hobbies                  0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_date                    0
# incident_type                    0
# collision_type                 178
# incident_severity                0
# authorities_contacted            0
# incident_state                   0
# incident_city                    0
# incident_location                0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# ...

# %% [markdown]
# collision_type, property_damage and police_report_available contains '?' which is converted to null and will be appropriatly replaced with values

# %%
maindt.collision_type.value_counts()
# Out:
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# Name: collision_type, dtype: int64

# %% [markdown]
# Collision type to be replaced with mode.

# %%
maindt['collision_type'].fillna(maindt['collision_type'].mode()[0], inplace=True)

# %%
maindt.property_damage.value_counts()
# Out:
# NO     338
# YES    302
# Name: property_damage, dtype: int64

# %%
maindt['property_damage'].fillna('NO', inplace=True)

# %%
maindt.police_report_available.value_counts()
# Out:
# NO     343
# YES    314
# Name: police_report_available, dtype: int64

# %%
maindt['police_report_available'].fillna('NO', inplace=True)

# %%
maindt.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# ...

# %% [markdown]
# Null values treated

# %%
sns.countplot(maindt['policy_state'], hue=maindt['fraud_reported'])
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='policy_state', ylabel='count'>

# %%
plt.figure(figsize=(20,20))
sns.displot(maindt, x="insured_occupation", hue="insured_sex")
plt.show()

# %% [markdown]
# Label Encoding the data

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

# %% [markdown]
# Splitting Date

# %%
maindt['policy_bind_date'] = pd.to_datetime(maindt['policy_bind_date'], errors = 'coerce')

# %%
maindt['fraud_reported'] = LE.fit_transform(maindt['fraud_reported'])

# %%
maindt.fraud_reported.value_counts()
# Out:
# 0    753
# 1    247
# Name: fraud_reported, dtype: int64

# %% [markdown]
# Encoding rest of the features

# %%
maindt['police_report_available'] = LE.fit_transform(maindt['police_report_available'])
maindt['auto_make'] = LE.fit_transform(maindt['auto_make'])
maindt['auto_model'] = LE.fit_transform(maindt['auto_model'])
maindt['incident_state'] = LE.fit_transform(maindt['incident_state'])
maindt['incident_city'] = LE.fit_transform(maindt['incident_city'])
maindt['property_damage'] = LE.fit_transform(maindt['property_damage'])
maindt['collision_type'] = LE.fit_transform(maindt['collision_type'])
maindt['incident_severity'] = LE.fit_transform(maindt['incident_severity'])
maindt['authorities_contacted'] = LE.fit_transform(maindt['authorities_contacted'])

# %%
maindt['incident_date'] = pd.to_datetime(maindt['incident_date'], errors = 'coerce')
maindt['incident_month'] = maindt['incident_date'].dt.month
maindt['incident_day'] = maindt['incident_date'].dt.day

# %%
maindt['incident_type'] = LE.fit_transform(maindt['incident_type'])

# %%
maindt['insured_occupation'] = LE.fit_transform(maindt['insured_occupation'])
maindt['insured_hobbies'] = LE.fit_transform(maindt['insured_hobbies'])
maindt['insured_relationship'] = LE.fit_transform(maindt['insured_relationship'])
maindt['policy_csl'] = LE.fit_transform(maindt['policy_csl'])
maindt['insured_sex'] = LE.fit_transform(maindt['insured_sex'])
maindt['insured_education_level'] = LE.fit_transform(maindt['insured_education_level'])
maindt['policy_state'] = LE.fit_transform(maindt['policy_state'])
maindt['policy_csl'] = LE.fit_transform(maindt['policy_csl'])

# %% [markdown]
# Also columns policy_number , policy_bind_date, incident_date and incident_location are of no use hence will be dropped.

# %%
maindt = maindt.drop(['policy_number','policy_bind_date', 'incident_date','incident_location'], axis=1)

# %% [markdown]
# Checking for skewness

# %%
plt.figure(figsize=(20,50))
colcount = len(maindt.columns)
x=1
for col in maindt:
    if x <= colcount:
        ax= plt.subplot(10,4,x)
        sns.distplot(maindt[col])
        plt.xlabel(col,fontsize=10)
    x=x+1
plt.show()
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Checking for multi collinearity

# %%
plt.figure(figsize=(20,20))
sns.heatmap(maindt.corr(), color = "k", annot=True  )
# Out:
# <AxesSubplot:>

# %% [markdown]
# Checking for outliers

# %%
plt.figure(figsize=(20,50))
colcount = len(maindt.columns)
x=1
for col in maindt:
    if x <= colcount:
        ax= plt.subplot(10,4,x)
        sns.boxplot(maindt[col],orient='v')
        plt.xlabel(col,fontsize=10)
    x=x+1
plt.show()
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
# ...

# %% [markdown]
# Not much outlier detected

# %%
sns.countplot(maindt['fraud_reported'])
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# Imbalance Issue

# %%
x= maindt.drop(columns=['fraud_reported'])
y= maindt['fraud_reported']


from imblearn.over_sampling import SMOTE
obj = SMOTE()
x, y = obj.fit_resample(x,y)

# %%
x.head(10)
# Out:
#    months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                 328   48             2           1               1000
# 1                 228   42             1           1               2000
# 2                 134   29             2           0               2000
# 3                 256   41             0           1               2000
# 4                 228   44             0           2               1000
# 5                 256   39             2           1               1000
# 6                 137   34             1           1               1000
# 7                 165   37             0           0               1000
# 8                  27   33             0           0                500
# 9                 212   42             0           0                500
#
#    policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# 0                1406.91               0       466132            1
# ...

# %% [markdown]
# Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
maxAccu = 0
maxRS = 0

for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=i)
    lg = LogisticRegression()
    lg.fit(x_train, y_train)
    pred = lg.predict(x_test)
    acc = accuracy_score(y_test, pred)
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
print("Best accuracy is: ",maxAccu,"on Random State: ",maxRS)
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=49)

# %% [markdown]
# Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
predlr = lr.predict(x_test)
print("Accuracy Score: {}".format(accuracy_score(y_test, predlr)*100))
print("f1_Score: {}".format(f1_score(y_test, predlr)*100))
print(confusion_matrix(y_test, predlr))
print(classification_report(y_test, predlr))
# Out:
# Accuracy Score: 57.824933687002655
# f1_Score: 58.70129870129871
# [[105  84]
#  [ 75 113]]
#               precision    recall  f1-score   support
#
#            0       0.58      0.56      0.57       189
#            1       0.57      0.60      0.59       188
#
#     accuracy                           0.58       377
#    macro avg       0.58      0.58      0.58       377
# weighted avg       0.58      0.58      0.58       377
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Decision Tree

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)
preddtc = dtc.predict(x_test)
print("Accuracy Score: {}".format(accuracy_score(y_test, preddtc)*100))
print("f1_Score: {}".format(f1_score(y_test, preddtc)*100))
print(confusion_matrix(y_test, preddtc))
print(classification_report(y_test, preddtc))
# Out:
# Accuracy Score: 83.28912466843501
# f1_Score: 83.63636363636363
# [[153  36]
#  [ 27 161]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       189
#            1       0.82      0.86      0.84       188
#
#     accuracy                           0.83       377
#    macro avg       0.83      0.83      0.83       377
# weighted avg       0.83      0.83      0.83       377

# %% [markdown]
# Random Forest Classifier

# %%
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
predrfc = rfc.predict(x_test)
print("Accuracy Score: {}".format(accuracy_score(y_test, predrfc)*100))
print("f1_Score: {}".format(f1_score(y_test, predrfc)*100))
print(confusion_matrix(y_test, predrfc))
print(classification_report(y_test, predrfc))
# Out:
# Accuracy Score: 88.3289124668435
# f1_Score: 88.35978835978835
# [[166  23]
#  [ 21 167]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       189
#            1       0.88      0.89      0.88       188
#
#     accuracy                           0.88       377
#    macro avg       0.88      0.88      0.88       377
# weighted avg       0.88      0.88      0.88       377

# %% [markdown]
# Knn Classifier

# %%
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
predknn = knn.predict(x_test)
print("Accuracy Score: {}".format(accuracy_score(y_test, predknn)*100))
print("f1_Score: {}".format(f1_score(y_test, predknn)*100))
print(confusion_matrix(y_test, predknn))
print(classification_report(y_test, predknn))
# Out:
# Accuracy Score: 69.76127320954907
# f1_Score: 73.48837209302326
# [[105  84]
#  [ 30 158]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.56      0.65       189
#            1       0.65      0.84      0.73       188
#
#     accuracy                           0.70       377
#    macro avg       0.72      0.70      0.69       377
# weighted avg       0.72      0.70      0.69       377

# %% [markdown]
# Gaussain NB

# %%
gnb = GaussianNB()
gnb.fit(x_train, y_train)
predgnb = gnb.predict(x_test)
print("Accuracy Score: {}".format(accuracy_score(y_test, predgnb)*100))
print("f1_Score: {}".format(f1_score(y_test, predgnb)*100))
print(confusion_matrix(y_test, predgnb))
print(classification_report(y_test, predgnb))
# Out:
# Accuracy Score: 63.395225464190986
# f1_Score: 70.76271186440678
# [[ 72 117]
#  [ 21 167]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.38      0.51       189
#            1       0.59      0.89      0.71       188
#
#     accuracy                           0.63       377
#    macro avg       0.68      0.63      0.61       377
# weighted avg       0.68      0.63      0.61       377

# %% [markdown]
# Cross Validating

# %%
models = []
models.append(('Logistic Regression', LogisticRegression()))
models.append(('Naive Bayes', GaussianNB()))
models.append(('Decision Tree', DecisionTreeClassifier()))
models.append(('Random Forest', RandomForestClassifier()))
models.append(('KNN', KNeighborsClassifier()))

maxx_acc = 0
for name, model in models:
    kfold = KFold(n_splits=10)
    cv = cross_val_score(model, x_train, y_train, cv=kfold, scoring='accuracy')
    result = cv.mean()
    print('{}: {:.2f}'.format(name, result*100))
    if result > maxx_acc:
        maxx_acc = result
        b_model = name
print("The best model is {} with the accuracy {:.2f}".format(b_model, maxx_acc*100))
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# Random forest comes out to be the best model

# %% [markdown]
# Hyper parameter tuning

# %%
param = {'n_estimators': np.arange(50, 150, 10),
            'criterion': ['gini', 'entropy'],
            'max_depth': np.arange(2,7)}

# %%
GCV = GridSearchCV(RandomForestClassifier(), param, cv=kfold)
GCV.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=False),
#              estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([2, 3, 4, 5, 6]),
#                          'n_estimators': array([ 50,  60,  70,  80,  90, 100, 110, 120, 130, 140])})

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 6, 'n_estimators': 100}

# %%
mod = RandomForestClassifier(criterion='entropy', max_depth=6, n_estimators=100)
mod.fit(x_train, y_train)
prediction = mod.predict(x_test)
print("Accuracy Score: {:.2f}".format(accuracy_score(y_test, prediction)*100))
# Out:
# Accuracy Score: 85.94

# %% [markdown]
# Plotting AUC ROC curve

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

pred_prob1 = gnb.predict_proba(x_test)
pred_prob2 = dtc.predict_proba(x_test)
pred_prob3 = knn.predict_proba(x_test)
pred_prob4 = rfc.predict_proba(x_test)
pred_prob5 = lr.predict_proba(x_test)

# %%
fpr1, tpr1, thresh1 = roc_curve(y_test, pred_prob1[:,1], pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_test, pred_prob2[:,1], pos_label=1)
fpr3, tpr3, thresh3 = roc_curve(y_test, pred_prob3[:,1], pos_label=1)
fpr4, tpr4, thresh4 = roc_curve(y_test, pred_prob4[:,1], pos_label=1)
fpr5, tpr5, thresh5 = roc_curve(y_test, pred_prob5[:,1], pos_label=1)


random_prob = [0 for i in range(len(y_test))]
fpr, tpr, _ = roc_curve(y_test, random_prob, pos_label=1)

# %%
auc_score1 = roc_auc_score(y_test, pred_prob1[:,1])
auc_score2 = roc_auc_score(y_test, pred_prob2[:,1])
auc_score3 = roc_auc_score(y_test, pred_prob3[:,1])
auc_score4 = roc_auc_score(y_test, pred_prob4[:,1])
auc_score5 = roc_auc_score(y_test, pred_prob5[:,1])
print('auc_score for GaussianNB: {:.2f}'.format(auc_score1*100))
print('auc_score for Decision Tree: {:.2f}'.format(auc_score2*100))
print('auc_score for K Nearest Neighbors: {:.2f}'.format(auc_score3*100))
print('auc_score for Random Forest: {:.2f}'.format(auc_score4*100))
print('auc_score for Logistic Regression: {:.2f}'.format(auc_score5*100))
# Out:
# auc_score for GaussianNB: 67.62
# auc_score for Decision Tree: 83.30
# auc_score for K Nearest Neighbors: 77.06
# auc_score for Random Forest: 96.05
# auc_score for Logistic Regression: 61.90

# %%
plt.style.use('seaborn')
plt.figure(figsize=(5,5))


plt.plot(fpr1, tpr1, linestyle='--', color='red', label='GaussianNB')
plt.plot(fpr2, tpr2, linestyle='--', color='orange', label='Decision Tree')
plt.plot(fpr3, tpr3, linestyle='--', color='blue', label='K Nearest Neighbors')
plt.plot(fpr4, tpr4, linestyle='--', color='green', label='Random Forest')
plt.plot(fpr5, tpr5, linestyle='--', color='purple', label='Logistic Regression')
plt.plot(fpr, tpr, linestyle='--', color='black')


plt.title('ROC Curve')


plt.xlabel('False Positive Rate')


plt.ylabel('True Positive Rate')
plt.legend(loc='best')
plt.show()

# %%
import joblib
joblib.dump(mod, 'Final.pkl')
# Out:
# ['Final.pkl']
