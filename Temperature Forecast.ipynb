# %%
import pandas as pd
import numpy as np

# %%
maindt = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Dataset2/main/temperature.csv")

# %%
maindt
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
maindt.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %% [markdown]
# Renaming columns

# %%
maindt.rename(columns={'LDAPS_RHmin': 'RHmin', 'LDAPS_RHmax': 'RHmax','LDAPS_Tmax_lapse':'Tmax_lapse',
                  'LDAPS_Tmin_lapse':'Tmin_lapse','LDAPS_WS':'WS','LDAPS_LH':'LH',
                  'LDAPS_CC1':'CC1','LDAPS_CC2':'CC2','LDAPS_CC3':'CC3','LDAPS_CC4':'CC4',
                    'LDAPS_PPT1':'PPT1','LDAPS_PPT2':'PPT2','LDAPS_PPT3':'PPT3','LDAPS_PPT4':'PPT4','Solar radiation':'SoLR'}, inplace=True)

# %%
maindt.isnull().sum()
# Out:
# station          2
# Date             2
# Present_Tmax    70
# Present_Tmin    70
# RHmin           75
# RHmax           75
# Tmax_lapse      75
# Tmin_lapse      75
# WS              75
# LH              75
# CC1             75
# CC2             75
# CC3             75
# CC4             75
# PPT1            75
# PPT2            75
# PPT3            75
# PPT4            75
# lat              0
# lon              0
# DEM              0
# Slope            0
# SoLR             0
# Next_Tmax       27
# Next_Tmin       27
# dtype: int64

# %% [markdown]
# Null values in majority of columns

# %% [markdown]
# Updating Station values

# %%
maindt.station.value_counts()
# Out:
# 15.0    310
# 21.0    310
# 7.0     310
# 23.0    310
# 8.0     310
# 3.0     310
# 10.0    310
# 16.0    310
# 11.0    310
# 2.0     310
# 13.0    310
# 12.0    310
# 9.0     310
# 24.0    310
# 4.0     310
# 25.0    310
# 22.0    310
# 17.0    310
# 19.0    310
# 20.0    310
# 1.0     310
# 5.0     310
# 18.0    310
# 6.0     310
# 14.0    310
# Name: station, dtype: int64

# %%
maindt.fillna({'station': 1.0}, inplace=True)

# %%
maindt.Date.value_counts()
# Out:
# 27-08-2013    25
# 27-08-2016    25
# 20-08-2016    25
# 28-07-2014    25
# 25-07-2015    25
#               ..
# 02-08-2017    25
# 10-08-2016    25
# 04-08-2015    25
# 29-08-2016    25
# 28-08-2015    25
# Name: Date, Length: 310, dtype: int64

# %%
maindt.fillna({'Date': '31-08-2017'}, inplace=True)

# %%
maindt.head(10)
# Out:
#    station        Date  Present_Tmax  Present_Tmin      RHmin      RHmax  \
# 0      1.0  30-06-2013          28.7          21.4  58.255688  91.116364
# 1      2.0  30-06-2013          31.9          21.6  52.263397  90.604721
# 2      3.0  30-06-2013          31.6          23.3  48.690479  83.973587
# 3      4.0  30-06-2013          32.0          23.4  58.239788  96.483688
# 4      5.0  30-06-2013          31.4          21.9  56.174095  90.155128
# 5      6.0  30-06-2013          31.9          23.5  52.437126  85.307251
# 6      7.0  30-06-2013          31.4          24.4  56.287189  81.019760
# 7      8.0  30-06-2013          32.1          23.6  52.326218  78.004539
# 8      9.0  30-06-2013          31.4          22.0  55.338791  80.784607
# 9     10.0  30-06-2013          31.6          20.5  56.651203  86.849632
#
#    Tmax_lapse  Tmin_lapse        WS          LH  ...  PPT2  PPT3  PPT4  \
# 0   28.074101   23.006936  6.818887   69.451805  ...   0.0   0.0   0.0
# ...

# %%
maindt.describe()
# Out:
#            station  Present_Tmax  Present_Tmin        RHmin        RHmax  \
# count  7752.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     12.996904     29.768211     23.225059    56.759372    88.374804
# std       7.213213      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#         Tmax_lapse   Tmin_lapse           WS           LH          CC1  ...  \
# count  7677.000000  7677.000000  7677.000000  7677.000000  7677.000000  ...
# mean     29.613447    23.512589     7.097875    62.505019     0.368774  ...
# std       2.947191     2.345347     2.183836    33.730589     0.262458  ...
# ...

# %% [markdown]
# Extracting day and month from date

# %%
maindt['Date']=pd.to_datetime(maindt['Date'])
maindt['Month'] = pd.DatetimeIndex(maindt['Date']).month
maindt['Day'] = maindt['Date'].dt.day
maindt.drop(['Date'],axis=1,inplace=True)

# %% [markdown]
# For ret columns filling null values with the mean value of each column

# %%
for i in maindt.columns:
    maindt[i]=maindt[i].fillna(maindt[i].mean())

# %%
maindt.isnull().sum()
# Out:
# station         0
# Present_Tmax    0
# Present_Tmin    0
# RHmin           0
# RHmax           0
# Tmax_lapse      0
# Tmin_lapse      0
# WS              0
# LH              0
# CC1             0
# CC2             0
# CC3             0
# CC4             0
# PPT1            0
# PPT2            0
# PPT3            0
# PPT4            0
# lat             0
# lon             0
# DEM             0
# Slope           0
# SoLR            0
# Next_Tmax       0
# Next_Tmin       0
# Month           0
# Day             0
# dtype: int64

# %% [markdown]
#  Null values taken care

# %% [markdown]
# Plotting line plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
for i in maindt.columns:
    sns.lineplot(x=i,y='Next_Tmax',data=maindt)
    plt.show()

# %%
plt.figure(figsize=(20,50))
colcount = len(maindt.columns)
x=1
for col in maindt:
    if x <= colcount:
        ax= plt.subplot(10,3,x)
        sns.distplot(maindt[col])
        plt.xlabel(col,fontsize=10)
    x=x+1
plt.show()
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# PPT1-PPT4 all are left skewed

# %% [markdown]
# Checking for outlier

# %%
plt.figure(figsize=(20,50))
colcount = len(maindt.columns)
x=1
for col in maindt:
    if x <= colcount:
        ax= plt.subplot(10,3,x)
        sns.boxplot(maindt[col])
        plt.xlabel(col,fontsize=10)
    x=x+1
plt.show()
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rooster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# PPT1 to PPT 4 has large number of outliers

# %% [markdown]
# Find multi collinearity issue

# %%
plt.figure(figsize=(30,30))
sns.heatmap(maindt.corr(), color = "k", annot=True  )
# Out:
# <AxesSubplot:>

# %% [markdown]
# Slightly high multi collinearity found for
# slope DEM
# CC2 - CC1
# CC3 - CC2

# %% [markdown]
# Removing Outlier with z score

# %%
maindt.skew()
# Out:
# station         0.000100
# Present_Tmax   -0.264137
# Present_Tmin   -0.367538
# RHmin           0.300220
# RHmax          -0.855015
# Tmax_lapse     -0.227880
# Tmin_lapse     -0.581763
# WS              1.579236
# LH              0.673757
# CC1             0.459458
# CC2             0.472350
# CC3             0.640735
# CC4             0.666482
# PPT1            5.393821
# PPT2            5.775355
# PPT3            6.457129
# PPT4            6.825464
# lat             0.087062
# lon            -0.285213
# DEM             1.723257
# Slope           1.563020
# SoLR           -0.511210
# Next_Tmax      -0.340200
# Next_Tmin      -0.404447
# Month          -0.705586
# Day             0.245283
# dtype: float64

# %%
from scipy.stats import zscore
z=np.abs(zscore(maindt.drop(columns=['Next_Tmax','Next_Tmin'])))

# %%
maindt2=maindt[(z<3).all(axis=1)]

# %%
maindt2.shape
# Out:
# (6907, 26)

# %%
maindt.shape
# Out:
# (7752, 26)

# %%
100-(6907/7752)*100
# Out:
# 10.900412796697623

# %% [markdown]
# More than 10% data is lost

# %% [markdown]
# using power transform method

# %%
from sklearn.preprocessing import power_transform

# %%
maindt2 = maindt.copy()

# %%
maindt.drop(['Next_Tmax','Next_Tmin'],axis=1,inplace=True)

# %%
maindt3=power_transform(maindt)
maindt3=pd.DataFrame(data=maindt3,columns=maindt.columns)
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3202: RuntimeWarning: overflow encountered in power
#   out[pos] = (np.power(x[pos] + 1, lmbda) - 1) / lmbda
# C:\Users\rooster\anaconda3\lib\site-packages\numpy\core\_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# C:\Users\rooster\anaconda3\lib\site-packages\numpy\core\_methods.py:216: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)

# %%
maindt3.skew()
# Out:
# station        -0.204739
# Present_Tmax   -0.035006
# Present_Tmin   -0.012048
# RHmin          -0.017469
# RHmax          -0.115143
# Tmax_lapse     -0.009351
# Tmin_lapse     -0.017827
# WS              0.002408
# LH              0.057403
# CC1             0.046757
# CC2             0.045326
# CC3             0.087933
# CC4             0.126895
# PPT1            1.404189
# PPT2            1.577808
# PPT3            1.747820
# PPT4            1.963848
# lat             0.000000
# lon            -0.198429
# DEM             0.039456
# Slope           0.233968
# SoLR           -0.176636
# Month           0.043780
# Day            -0.041940
# dtype: float64

# %%
maindt3['Next_Tmax']=maindt2['Next_Tmax']
maindt3['Next_Tmin']=maindt2['Next_Tmin']

# %% [markdown]
# Skewness for PPT 1 - PPT4 is large hence to be ignored

# %%
x=maindt3.iloc[:,0:24]
y_max=maindt3['Next_Tmax']
y_min=maindt3['Next_Tmin']
y_max=pd.DataFrame(data=y_max)
y_min=pd.DataFrame(data=y_min)

# %%
x.shape,y_max.shape,y_min.shape
# Out:
# ((7752, 24), (7752, 1), (7752, 1))

# %% [markdown]
# Standardizing the values

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

xt=sc.fit_transform(x)
xt=pd.DataFrame(xt,columns=x.columns)

# %%
xt
# Out:
#        station  Present_Tmax  Present_Tmin     RHmin     RHmax  Tmax_lapse  \
# 0    -1.859306     -0.408897     -0.797707  0.172680  0.272915   -0.556645
# 1    -1.647315      0.705123     -0.720130 -0.241770  0.185831    0.043756
# 2    -1.453783      0.595692     -0.027674 -0.501459 -0.773454    0.127214
# 3    -1.272913      0.741829      0.014910  0.171612  1.316777   -0.006660
# 4    -1.101532      0.523313     -0.602237  0.031496  0.110968   -0.208627
# ...        ...           ...           ...       ...       ...         ...
# 7747  1.312280     -2.023162     -2.270927 -2.395892 -1.326845   -1.111724
# 7748  1.427169     -2.023162     -2.087438 -2.681557 -1.470235   -0.902733
# 7749  1.540836     -2.049920     -2.180066 -2.803707 -1.474702   -0.600985
# 7750 -1.859306     -2.846187     -3.688005 -3.168120 -2.459357   -3.504186
# 7751 -1.859306      2.981037      3.233078  2.489550  2.143982    3.376037
#
# ...

# %%
x=xt

# %% [markdown]
# From heatmap lot of multi collinearity was seen hence removing those with PCA

# %%
from sklearn.decomposition import PCA

# %%
testPCA=PCA()
Y=testPCA.fit(x)

# %%
var_cumu=np.cumsum(Y.explained_variance_ratio_)*100
var_cumu
# Out:
# array([ 25.20605445,  38.07320356,  46.34314444,  52.98091021,
#         59.41671713,  64.91862548,  69.71045973,  73.98519594,
#         77.85631998,  81.4686899 ,  84.46691576,  86.88042214,
#         89.17756764,  91.29838964,  93.09147296,  94.62410372,
#         95.91412801,  96.95512843,  97.8863724 ,  98.67056462,
#         99.25171868,  99.72744549, 100.        , 100.        ])

# %%
FinalPCA=PCA(n_components=17)
final_x=FinalPCA.fit_transform(x)
finalx=pd.DataFrame(final_x)

# %%
finalx
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.353300  2.503422 -2.024326 -0.185177  0.332959 -0.569108  0.294639
# 1    -1.157812  0.654540 -0.521596 -0.473590  0.078806 -0.186316  1.433495
# 2    -1.410760 -0.266889  0.240818 -0.387900  0.671097 -0.933237  1.402167
# 3    -0.743598  0.948988 -1.586615 -0.174097 -0.465474 -0.111663  0.908646
# 4    -1.090262  0.852578 -0.570637 -0.234535 -0.199411  0.839750  2.018301
# ...        ...       ...       ...       ...       ...       ...       ...
# 7747 -2.929999  3.172160  4.213509 -1.437943 -1.004297  0.576889 -1.209970
# 7748 -3.050171  3.085601  4.137714 -1.258649 -0.700124 -0.005131 -1.411623
# 7749 -3.032140  3.080868  4.119377 -1.058535 -0.101439 -1.103248 -1.389521
# 7750 -2.812867  4.969116  7.324037 -1.560404  1.344042 -4.239419  1.685294
# 7751  4.900362 -4.870195 -6.116655  3.937092 -1.958431  2.424007 -0.385208
#
# ...

# %%
x=finalx

# %%
x.describe()
# Out:
#                  0             1             2             3             4   \
# count  7.752000e+03  7.752000e+03  7.752000e+03  7.752000e+03  7.752000e+03
# mean   6.736957e-17  5.042406e-16  1.058665e-16  8.753461e-17 -3.308327e-17
# std    2.407933e+00  1.720415e+00  1.379250e+00  1.235671e+00  1.216728e+00
# min   -4.775087e+00 -5.552132e+00 -6.116655e+00 -4.192496e+00 -3.727227e+00
# 25%   -1.818449e+00 -1.203627e+00 -9.868530e-01 -8.157006e-01 -7.875982e-01
# 50%   -4.595254e-01 -6.946987e-02 -4.955976e-02  3.829606e-02 -5.807657e-02
# 75%    1.603395e+00  1.131996e+00  9.465193e-01  8.521766e-01  7.529144e-01
# max    7.967562e+00  6.748381e+00  7.324037e+00  4.415769e+00  3.968494e+00
#
#                  5             6             7             8             9   \
# count  7.752000e+03  7.752000e+03  7.752000e+03  7.752000e+03  7.752000e+03
# mean   1.848653e-16 -8.008730e-17  5.900566e-17  3.792403e-17  3.855418e-17
# ...

# %% [markdown]
# Building Model

# %% [markdown]
# Calculating Next_Tmin

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y_min,test_size=.25,random_state=49)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Lasso,Ridge,ElasticNet
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

lr = LinearRegression()
sv=SVR(kernel='rbf')
dt=DecisionTreeRegressor()
rf=RandomForestRegressor()
kn=KNeighborsRegressor()
ab=AdaBoostRegressor()
gb=GradientBoostingRegressor()
ls=Lasso()
rd=Ridge()

model=[lr,sv,dt,rf,kn,ab,gb,ls,rd]
kf = KFold(n_splits=5, random_state=54, shuffle=True)

train=[]
test=[]
Mse=[]
cv=[]

for m in model:
    m.fit(x_train,y_train)
    pred_train=m.predict(x_train)
    pred_test=m.predict(x_test)
    train_score=r2_score(y_train,pred_train)
    train.append(train_score*100)
    test_score=r2_score(y_test,pred_test)
    test.append(test_score*100)
    mse = mean_squared_error(y_test,pred_test)
    Mse.append(mse)
    score=cross_val_score(m,x,y_max,cv=kf)
    cv.append(score.mean()*100)
    
Performance={'Model':['Linear Regression','SupportVector','DecisionTree','RandomForest','KNN','AdaBoost','GradientBoosting','Lasso','Ridge'],
             'Training Score':train,
            'Test Score':test,
            'Mean Square Error':Mse,
            'Cross Validation Score': cv}
Performance=pd.DataFrame(data=Performance)
Performance
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %% [markdown]
# SVR comes out to bes best model with 87% test score and cv of 86%

# %% [markdown]
# Hyper tuning SVR

# %%
parameters = {'kernel': ('rbf','poly'),'epsilon':[0.1,0.2,0.3], 'C':[1.0,1.5, 10],'gamma': ['scale', 'auto']}

# %%
from sklearn.model_selection import GridSearchCV
GCV=GridSearchCV(SVR(),parameters,cv=3)
GCV.fit(x_train,y_train)

GCV.best_params_
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %%
Finalmod_min=SVR(kernel='rbf',C=10,epsilon=0.1,gamma='auto')
Finalmod_min.fit(x_train,y_train)
pred_test=Finalmod_min.predict(x_test)
R2=r2_score(y_test,pred_test)
scores=cross_val_score(Finalmod_min,x,y_min,cv=kf)
MSE = mean_squared_error(y_test,pred_test)
print('SupportVectorRegressor Performance')
print('---------------------------------------------------')
print('Accuracy Score', R2*100)
print('Cross Validation score',scores.mean()*100)
print('Mean Square Error',MSE)
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %% [markdown]
# SVR is the best model with Accuracy score of 91 and CV 92

# %%
import joblib
joblib.dump(Finalmod_min,'Next_Tmin.obj')
# Out:
# ['Next_Tmin.obj']

# %% [markdown]
# Testing for Next_Tmax

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y_max,test_size=.25,random_state=83)

# %%
sv=SVR(kernel='rbf')
dt=DecisionTreeRegressor()
rf=RandomForestRegressor()
kn=KNeighborsRegressor()
ab=AdaBoostRegressor()
gb=GradientBoostingRegressor()
ls=Lasso()
rd=Ridge()

model=[lr,sv,dt,rf,kn,ab,gb,ls,rd]
kf = KFold(n_splits=5, random_state=54, shuffle=True)

train=[]
test=[]
Mse=[]
cv=[]

for m in model:
    m.fit(x_train,y_train)
    pred_train=m.predict(x_train)
    pred_test=m.predict(x_test)
    train_score=r2_score(y_train,pred_train)
    train.append(train_score*100)
    test_score=r2_score(y_test,pred_test)
    test.append(test_score*100)
    mse = mean_squared_error(y_test,pred_test)
    Mse.append(mse)
    score=cross_val_score(m,x,y_max,cv=kf)
    cv.append(score.mean()*100)
    
Performance={'Model':['Linear Regression','SupportVector','DecisionTree','RandomForest','KNN','AdaBoost','GradientBoosting','Lasso','Ridge'],
             'Training Score':train,
            'Test Score':test,
            'Mean Square Error':Mse,
            'Cross Validation Score': cv}
Performance=pd.DataFrame(data=Performance)
Performance
# Out:
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rooster\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %% [markdown]
# KNN model comes out to be best model

# %%
parameters = {'n_neighbors':[5,6,7,8,9,10],
          'leaf_size':[1,2,3,5],
          'weights':['uniform', 'distance'],
          'algorithm':['auto', 'ball_tree','kd_tree','brute'],
          'n_jobs':[-1]}

# %%
GCV=GridSearchCV(KNeighborsRegressor(),parameters,cv=3)
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 1,
#  'n_jobs': -1,
#  'n_neighbors': 6,
#  'weights': 'distance'}

# %%
Finalmod_max=KNeighborsRegressor(algorithm='auto',leaf_size=1,n_jobs=-1,n_neighbors=6,weights='distance')
Finalmod_max.fit(x_train,y_train)
pred_test=Finalmod_max.predict(x_test)
R2=r2_score(y_test,pred_test)
scores=cross_val_score(Finalmod_max,x,y_max,cv=kf)
MSE = mean_squared_error(y_test,pred_test)
print('KNeighborsRegressor Performance')
print('---------------------------------------------------')
print('Accuracy Score', R2*100)
print('Cross Validation score',scores.mean()*100)
print('Mean Square Error',MSE)
# Out:
# KNeighborsRegressor Performance
# ---------------------------------------------------
# Accuracy Score 88.2127789753797
# Cross Validation score 87.54410934617779
# Mean Square Error 1.1703613558036905

# %% [markdown]
# With 88% accuracy score and 87% CV KNN is the best model

# %%
import joblib
joblib.dump(Finalmod_max,'Next_Tmin.obj')
# Out:
# ['Next_Tmin.obj']
